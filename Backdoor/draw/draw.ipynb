# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
mlp_noniid_01_10_1 = np.load('./Trojan-backdoorsaccuracy_green_car_backdoor.npy')
plt.plot(mlp_noniid_01_10_1)
plt.title('Data')
plt.xlabel('1')
plt.ylabel('2')
plt.show()

# %%
mlp_noniid_01_10_1 = np.load('./Trojan-backdoorsaccuracy_green_car_backdoor.npy')
plt.plot(mlp_noniid_01_10_1)
plt.title('Data')
plt.xlabel('1')
plt.ylabel('2')
plt.show()
